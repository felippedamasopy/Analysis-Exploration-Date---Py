# %% [markdown]
# <a href="https://colab.research.google.com/github/felippedamasopy/Analysis-Exploration-Date---Py/blob/main/Estatistica_Descritiva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/residencia (1).csv', index = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-5e7ca0fe5cde> in <module>
# ----> 1 df = pd.read_csv('/content/residencia (1).csv', index = True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1         Tipo           Bairro  Quartos  Vagas  \
# 0           0             0    Quitinete       Copacabana        1      0
# 1           1             1         Casa  Jardim Botânico        2      0
# 2           2             3  Apartamento           Centro        1      0
# 3           3             4  Apartamento     Higienópolis        1      0
# 4           4             6  Apartamento         Cachambi        2      0
#
#    Suites  Area   Valor  Condominio  IPTU  Valor M2 Tipos Agregado
# 0       0    40  1700.0       500.0  60.0     42.50    Apartamento
# 1       1   100  7000.0         0.0   0.0     70.00           Casa
# 2       0    15   800.0       390.0  20.0     53.33    Apartamento
# 3       0    48   800.0       230.0   0.0     16.67    Apartamento
# 4       0    50  1300.0       301.0  17.0     26.00    Apartamento

# %%
list(df['Bairro'].drop_duplicates())
# Out:
# ['Copacabana',
#  'Jardim Botânico',
#  'Centro',
#  'Higienópolis',
#  'Cachambi',
#  'Barra da Tijuca',
#  'Ramos',
#  'Grajaú',
#  'Lins de Vasconcelos',
#  'Botafogo',
#  'Taquara',
#  'Freguesia (Jacarepaguá)',
#  'Tijuca',
#  'Olaria',
#  'Leblon',
#  'Ipanema',
#  'Campo Grande',
#  'Recreio dos Bandeirantes',
#  'Jardim Oceânico',
#  'Humaitá',
#  'Península',
#  'Méier',
#  'Vargem Pequena',
#  'Maracanã',
#  'Jacarepaguá',
#  'São Conrado',
#  'Vila Valqueire',
#  'Gávea',
#  'Cosme Velho',
#  'Bonsucesso',
#  'Todos os Santos',
#  'Laranjeiras',
#  'Itanhangá',
#  'Flamengo',
#  'Piedade',
#  'Lagoa',
#  'Catete',
#  'Jardim Carioca',
#  'Benfica',
#  'Glória',
#  'Praça Seca',
#  'Vila Isabel',
#  'Engenho Novo',
#  'Engenho de Dentro',
#  'Pilares',
#  'Arpoador',
#  'Água Santa',
#  'São Cristóvão',
#  'Ilha do Governador',
#  'Jardim Sulacap',
#  'Oswaldo Cruz',
#  'Vila da Penha',
#  'Anil',
#  'Vargem Grande',
#  'Tanque',
#  'Vaz Lobo',
#  'Madureira',
# ...

# %%
bairro = ['Copacabana',
 'Jardim Botânico',
 'Centro',
 'Higienópolis',
 'Cachambi',
 'Barra da Tijuca',
 'Ramos',
 'Grajaú',
 'Lins de Vasconcelos',
 'Botafogo',
 'Taquara',
 'Freguesia (Jacarepaguá)',
 'Tijuca',
 'Olaria',
 'Leblon',
 'Ipanema',
 'Campo Grande',
 'Recreio dos Bandeirantes',
 'Jardim Oceânico',
 'Humaitá',
 'Península',
 'Méier',
 'Vargem Pequena',
 'Maracanã',
 'Jacarepaguá',
 'São Conrado',
 'Vila Valqueire',
 'Gávea',
 'Cosme Velho',
 'Bonsucesso',
 'Todos os Santos',
 'Laranjeiras',
 'Itanhangá',
 'Flamengo',
 'Piedade',
 'Lagoa',
 'Catete',
 'Jardim Carioca',
 'Benfica',
 'Glória',
 'Praça Seca',
 'Vila Isabel',
 'Engenho Novo',
 'Engenho de Dentro',
 'Pilares',
 'Arpoador',
 'Água Santa',
 'São Cristóvão',
 'Ilha do Governador',
 'Jardim Sulacap',
 'Oswaldo Cruz',
 'Vila da Penha',
 'Anil',
 'Vargem Grande',
 'Tanque',
 'Vaz Lobo',
 'Madureira',
 'São Francisco Xavier',
 'Pechincha',
 'Leme',
 'Irajá',
 'Quintino Bocaiúva',
 'Urca',
 'Penha',
 'Gardênia Azul',
 'Rio Comprido',
 'Andaraí',
 'Santa Teresa',
 'Inhaúma',
 'Marechal Hermes',
 'Curicica',
 'Santíssimo',
 'Moneró',
 'Camorim',
 'Cascadura',
 'Praia da Bandeira',
 'Saúde',
 'Joá',
 'Realengo',
 'Fátima',
 'Jardim Guanabara',
 'Inhoaíba',
 'Rocha',
 'Jabour',
 'Braz de Pina',
 'Praça da Bandeira',
 'Vila Kosmos',
 'Vista Alegre',
 'Encantado',
 'Campinho',
 'Guaratiba',
 'Riachuelo',
 'Bangu',
 'Lapa',
 'Catumbi',
 'Penha Circular',
 'Abolição',
 'Tomás Coelho',
 'Colégio',
 'Pavuna',
 'Santa Cruz',
 'Alto da Boa Vista',
 'Cidade Nova',
 'Bento Ribeiro',
 'Estácio',
 'Jardim América',
 'Cordovil',
 'Caju',
 'Pedra de Guaratiba',
 'Padre Miguel',
 'Paciência',
 'Del Castilho',
 'Sampaio',
 'Anchieta',
 'Icaraí',
 'Senador Vasconcelos',
 'Rocha Miranda',
 'Gamboa',
 'Maria da Graça',
 'Barra de Guaratiba',
 'Vicente de Carvalho',
 'Paquetá',
 'Largo do Machado',
 'Parada de Lucas',
 'Freguesia (Ilha do Governador)',
 'Portuguesa',
 'Guadalupe',
 'Parque Anchieta',
 'Turiaçu',
 'Pitangueiras',
 'Vila Militar',
 'Vidigal',
 'Senador Camará',
 'Usina',
 'Vigário Geral',
 'Cosmos',
 'Jacaré',
 'Cocotá',
 'Honório Gurgel',
 'Engenho da Rainha',
 'Cachamorra',
 'Zumbi',
 'Tauá',
 'Santo Cristo',
 'Ribeira',
 'Magalhães Bastos',
 'Cacuia',
 'Bancários',
 'Cavalcanti',
 'Rio da Prata',
 'Cidade Jardim',
 'Coelho Neto']

# %%
selecao = df['Bairro'].isin(bairro)

# %%
selecao
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 22577    True
# 22578    True
# 22579    True
# 22580    True
# 22581    True
# Name: Bairro, Length: 22582, dtype: bool

# %%
dados = df[selecao]

# %%
grupo_bairro = dados.groupby(dados['Bairro'])

# %%
grupo_bairro

# %%
grupo_bairro.mean().round(2)
# Out:
#                    Unnamed: 0  Unnamed: 0.1  Quartos  Vagas  Suites    Area  \
# Bairro
# Abolição             13275.93      19465.93     1.87   0.60    0.00   77.80
# Alto da Boa Vista    11431.43      16793.57     3.29   1.86    1.14  530.00
# Anchieta             11737.50      17220.50     2.00   1.00    0.00   78.50
# Andaraí              11232.58      16476.44     1.95   0.60    0.24   74.03
# Anil                 10332.83      15175.06     2.55   1.37    0.73  134.59
# ...                       ...           ...      ...    ...     ...     ...
# Vila Valqueire       10483.55      15375.71     2.31   1.49    0.45  115.08
# Vila da Penha        11611.69      17026.83     1.99   0.54    0.28   72.53
# Vista Alegre         12133.00      17787.12     2.00   0.75    0.06   70.00
# Zumbi                10985.50      16179.50     2.50   0.50    0.00   77.00
# Água Santa           10464.89      15353.78     1.89   0.56    0.00   56.22
#
# ...

# %%
for bairro , dados in grupo_bairro:
  print('{} - > {}'.format(bairro, dados.Valor.mean().round(2)))
# Out:
# Abolição - > 1195.33
# Alto da Boa Vista - > 7685.71
# Anchieta - > 875.0
# Andaraí - > 1531.4
# Anil - > 2048.87
# Arpoador - > 11189.13
# Bancários - > 1825.0
# Bangu - > 1016.0
# Barra da Tijuca - > 7004.27
# Barra de Guaratiba - > 5550.0
# Benfica - > 996.0
# Bento Ribeiro - > 1237.92
# Bonsucesso - > 1337.58
# Botafogo - > 9056.34
# Braz de Pina - > 1115.0
# Cachambi - > 1216.14
# Cachamorra - > 3000.0
# Cacuia - > 916.67
# Caju - > 850.0
# Camorim - > 2935.71
# Campinho - > 1037.33
# Campo Grande - > 1570.16
# Cascadura - > 948.71
# Catete - > 2470.37
# Catumbi - > 1112.5
# Cavalcanti - > 595.0
# Centro - > 1523.77
# Cidade Jardim - > 12000.0
# Cidade Nova - > 1471.43
# Cocotá - > 1883.33
# Coelho Neto - > 700.0
# Colégio - > 885.0
# Copacabana - > 4113.59
# Cordovil - > 905.56
# Cosme Velho - > 5551.56
# Cosmos - > 658.33
# Curicica - > 1613.67
# Del Castilho - > 1261.3
# Encantado - > 1050.0
# Engenho Novo - > 1182.76
# Engenho da Rainha - > 883.57
# ...

# %%
grupo_bairro[['Valor', 'Condominio']].mean().round(2)
# Out:
#                      Valor  Condominio
# Bairro
# Abolição           1195.33      191.40
# Alto da Boa Vista  7685.71      758.57
# Anchieta            875.00       19.75
# Andaraí            1531.40      492.63
# Anil               2048.87      455.85
# ...                    ...         ...
# Vila Valqueire     2214.51      260.59
# Vila da Penha      1260.58      232.68
# Vista Alegre       1114.38      210.06
# Zumbi              2150.00     1050.00
# Água Santa          861.11      269.44
#
# [152 rows x 2 columns]

# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])

# %%
sexo = alunos.groupby('Sexo')

# %%
sexo.mean().round(2)
# Out:
#       Idade  Notas  Aprovado
# Sexo
# F     31.25   5.82       0.5
# M     30.50   7.12       0.5

# %%
sexo = pd.DataFrame(sexo['Notas'].mean().round(2))

# %%
sexo
# Out:
#       Notas
# Sexo
# F      5.82
# M      7.12

# %%
sexo.columns = ['Notas Medias']

# %%
sexp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-03a0580a23d1> in <module>
# ----> 1 sexp
#
# NameError: name 'sexp' is not defined

# %%
sexo
# Out:
#       Notas Medias
# Sexo
# F             5.82
# M             7.12

# %%
grupo_bairro['Valor'].describe()
# Out:
#                    count         mean           std     min     25%     50%  \
# Bairro
# Abolição            15.0  1195.333333    425.321167   800.0   900.0  1180.0
# Alto da Boa Vista    7.0  7685.714286  11052.251441   600.0  1300.0  1850.0
# Anchieta             4.0   875.000000    132.287566   700.0   812.5   900.0
# Andaraí             98.0  1531.397959    775.015780   700.0  1200.0  1400.0
# Anil                71.0  2048.873239   1523.974643   300.0  1100.0  1500.0
# ...                  ...          ...           ...     ...     ...     ...
# Vila Valqueire      51.0  2214.509804   2985.984805   800.0  1025.0  1400.0
# Vila da Penha      104.0  1260.576923    644.656644   450.0   900.0  1100.0
# Vista Alegre        16.0  1114.375000    199.598555   700.0  1012.5  1200.0
# Zumbi                2.0  2150.000000    777.817459  1600.0  1875.0  2150.0
# Água Santa           9.0   861.111111    174.602724   600.0   800.0   850.0
#
#                       75%      max
# Bairro
# ...

# %%
grupo_bairro['Valor'].aggregate(['min', 'max'])
# Out:
#                       min      max
# Bairro
# Abolição            800.0   2300.0
# Alto da Boa Vista   600.0  30000.0
# Anchieta            700.0   1000.0
# Andaraí             700.0   8000.0
# Anil                300.0   7000.0
# ...                   ...      ...
# Vila Valqueire      800.0  16000.0
# Vila da Penha       450.0   4500.0
# Vista Alegre        700.0   1400.0
# Zumbi              1600.0   2700.0
# Água Santa          600.0   1200.0
#
# [152 rows x 2 columns]

# %%
grupo_bairro['Valor'].aggregate(['min', 'max']).rename(columns ={'min': 'Minima',
                                                        'max': 'Maxima'})
# Out:
#                    Minima   Maxima
# Bairro
# Abolição            800.0   2300.0
# Alto da Boa Vista   600.0  30000.0
# Anchieta            700.0   1000.0
# Andaraí             700.0   8000.0
# Anil                300.0   7000.0
# ...                   ...      ...
# Vila Valqueire      800.0  16000.0
# Vila da Penha       450.0   4500.0
# Vista Alegre        700.0   1400.0
# Zumbi              1600.0   2700.0
# Água Santa          600.0   1200.0
#
# [152 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.rc('figure', figsize =(20 ,10 ))

# %%
fig = grupo_bairro['Valor'].mean().plot.bar(color='blue')

# %%
fig = grupo_bairro['Valor'].std().plot.bar(color='blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor medio do aluguel', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor medio do aluguel')
